# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
alpha1 = 5
alpha2 = 1.0
alpha3 = 5
alpha4 = 5
#%%%%%%%%%%%%%%%%%%%%%%%%%% DQL%%%%%%%%%%%%%%%%%%%%%%
dql_L = pd.read_csv ("10_09_2022_02_02_00_DQN_total_rw.csv", names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
dql_L = np.array(dql_L)
dql_L  = np.transpose(dql_L) 
log_total_reward_DQL_L = dql_L[0]
Comp_reward_DQL_L = dql_L[1]
Cost_reward_DQL_L = dql_L[2]
Res_reward_DQL_L = dql_L[3]
Connect_reward_DQL_L = dql_L[4]
print(np.mean(Comp_reward_DQL_L[50:-1]))
print(np.mean(Cost_reward_DQL_L[50:-1]))
print(np.mean(Res_reward_DQL_L[50:-1]))
print(np.mean(Connect_reward_DQL_L[50:-1]))
#%
dql_10L = pd.read_csv ("03_09_2022_09_16_25_DQN_10L.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
dql_10L = np.array(dql_10L)
dql_10L  = np.transpose(dql_10L)
log_total_reward_DQL_10L = dql_10L[0]
Comp_reward_DQL_10L = dql_10L[1]
Cost_reward_DQL_10L = dql_10L[2]
Res_reward_DQL_10L = dql_10L[3]
Connect_reward_DQL_10L = dql_10L[4]
#%
dql_20L = pd.read_csv ("07_09_2022_09_38_45_DQN_20L.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
dql_20L = np.array(dql_20L)
dql_20L  = np.transpose(dql_20L)  
log_total_reward_DQL_20L = dql_20L[0]
Comp_reward_DQL_20L = dql_20L[1]
Cost_reward_DQL_20L = dql_20L[2]
Res_reward_DQL_20L = dql_20L[3]
Connect_reward_DQL_20L = dql_20L[4]

#%%%%%%%%%%%%%%%%%%%%%%%%%% DDQL%%%%%%%%%%%%%%%%%%%%%%
ddqn_L = pd.read_csv ("04_09_2022_00_01_02_DDQN_run.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ddqn_L = np.array(ddqn_L)
ddqn_L  = np.transpose(ddqn_L)  
log_total_reward_DDQN_L = ddqn_L[0]
Comp_reward_DDQN_L = ddqn_L[1]
Cost_reward_DDQN_L = ddqn_L[2]
Res_reward_DDQN_L = ddqn_L[3]
Connect_reward_DDQN_L = ddqn_L[4]
print(np.mean(Comp_reward_DDQN_L[50:-1]))
print(np.mean(Cost_reward_DDQN_L[50:-1]))
print(np.mean(Res_reward_DDQN_L[50:-1]))
print(np.mean(Connect_reward_DDQN_L[50:-1]))
#%
ddqn_10L = pd.read_csv ("07_09_2022_19_04_39_DDQN_10L.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ddqn_10L = np.array(ddqn_10L)
ddqn_10L  = np.transpose(ddqn_10L)  
log_total_reward_DDQN_10L = ddqn_10L[0]
Comp_reward_DDQN_10L = ddqn_10L[1]
Cost_reward_DDQN_10L = ddqn_10L[2]
Res_reward_DDQN_10L = ddqn_10L[3]
Connect_reward_DDQN_10L = ddqn_10L[4]
#%
ddqn_20L = pd.read_csv ("06_09_2022_17_02_25_DDQN_20L.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ddqn_20L = np.array(ddqn_20L)
ddqn_20L  = np.transpose(ddqn_20L)  
log_total_reward_DDQN_20L = ddqn_20L[0]
Comp_reward_DDQN_20L = ddqn_20L[1]
Cost_reward_DDQN_20L = ddqn_20L[2]
Res_reward_DDQN_20L = ddqn_20L[3]
Connect_reward_DDQN_20L = ddqn_20L[4]

#%%%%%%%%%%%%%%%%%%%%%%%%%% Random%%%%%%%%%%%%%%%%%%%%%%
ramdom_L = pd.read_csv ("05_09_2022_01_48_32_Random_total_rw.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ramdom_L = np.array(ramdom_L)
ramdom_L  = np.transpose(ramdom_L)  
log_total_reward_ramdom_L = ramdom_L[0]
Comp_reward_ramdom_L = ramdom_L[1]
Cost_reward_ramdom_L = ramdom_L[2]
Res_reward_ramdom_L = ramdom_L[3]
Connect_reward_ramdom_L = ramdom_L[4]
#%
ramdom_10L = pd.read_csv ("07_09_2022_07_56_42_Random_10L.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ramdom_10L = np.array(ramdom_10L)
ramdom_10L  = np.transpose(ramdom_10L)  
log_total_reward_ramdom_10L = ramdom_10L[0]
Comp_reward_ramdom_10L = ramdom_10L[1]
Cost_reward_ramdom_10L = ramdom_10L[2]
Res_reward_ramdom_10L = ramdom_10L[3]
Connect_reward_ramdom_10L = ramdom_10L[4]
#%
ramdom_20L = pd.read_csv ("07_09_2022_08_07_27_Random_20L.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ramdom_20L = np.array(ramdom_20L)
ramdom_20L  = np.transpose(ramdom_20L)  
log_total_reward_ramdom_20L = ramdom_20L[0]
Comp_reward_ramdom_20L = ramdom_20L[1]
Cost_reward_ramdom_20L = ramdom_20L[2]
Res_reward_ramdom_20L = ramdom_20L[3]
Connect_reward_ramdom_20L = ramdom_20L[4]

#%%%%%%%%%%%%%%%%%%%%%%%%%% Greedy%%%%%%%%%%%%%%%%%%%%%%
greedy_L = pd.read_csv ("09_09_2022_06_39_55_Greedy_total_rw.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
greedy_L = np.array(greedy_L)
greedy_L  = np.transpose(greedy_L)  
log_total_reward_greedy_L = greedy_L[0]
Comp_greedy_L = greedy_L[1]
Cost_greedy_L = greedy_L[2]
Res_greedy_L = greedy_L[3]
Connect_greedy_L = greedy_L[4]
#%
greedy_10L = pd.read_csv ("09_09_2022_04_51_07_Greedy_10L.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
greedy_10L = np.array(greedy_10L)
greedy_10L  = np.transpose(greedy_10L) 
log_total_reward_greedy_10L = greedy_10L[0]
Comp_greedy_10L = greedy_10L[1]
Cost_greedy_10L = greedy_10L[2]
Res_greedy_10L = greedy_10L[3]
Connect_greedy_10L = greedy_10L[4]
#%
greedy_20L = pd.read_csv ("09_09_2022_05_28_14_Greedy_20L.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
greedy_20L = np.array(greedy_20L)
greedy_20L  = np.transpose(greedy_20L)  
log_total_reward_greedy_20L = greedy_20L[0]
Comp_greedy_20L = greedy_20L[1]
Cost_greedy_20L = greedy_20L[2]
Res_greedy_20L = greedy_20L[3]
Connect_greedy_20L = greedy_20L[4]
# Out:
# 2.6937867332696186
# 0.0689527346254848
# 0.09524295630869743
# 0.09985708452429563
# 2.5790756300664786
# 0.05469061810505696
# 0.34187423438138026
# 0.10723764801959984

# %%
############### Plot 2##################################
aver_dqn_L = []
aver_ddqn_L = []
aver_greedy_L = []
aver_random_L = []
aver_dqn_10L = []
aver_ddqn_10L = []
aver_greedy_10L = []
aver_random_10L = []
aver_dqn_20L = []
aver_ddqn_20L = []
aver_greedy_20L = []
aver_random_20L = []
num_episodes = 100
step = (len(log_total_reward_DQL_L)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_L), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_L = log_total_reward_DQL_L[i:i+int(step)-1]
  aver_dqn_L.append(np.mean(dqn_eps_i_L))

  ddqn_eps_i_L = log_total_reward_DDQN_L[i:i+int(step)-1]
  aver_ddqn_L.append(np.mean(ddqn_eps_i_L))

  greedy_eps_i_L = log_total_reward_greedy_L[i:i+int(step)-1]
  aver_greedy_L.append(np.mean(greedy_eps_i_L))

  random_eps_i_L = log_total_reward_ramdom_L[i:i+int(step)-1]
  aver_random_L.append(np.mean(random_eps_i_L))

  # #%%%%%%10L%%%%%%%%% 
  dqn_eps_i_10L = log_total_reward_DQL_10L[i:i+int(step)-1]
  aver_dqn_10L.append(np.mean(dqn_eps_i_10L))

  ddqn_eps_i_10L = log_total_reward_DDQN_10L[i:i+int(step)-1]
  aver_ddqn_10L.append(np.mean(ddqn_eps_i_10L))

  greedy_eps_i_10L = log_total_reward_greedy_10L[i:i+int(step)-1]
  aver_greedy_10L.append(np.mean(greedy_eps_i_10L))

  random_eps_i_10L = log_total_reward_ramdom_10L[i:i+int(step)-1]
  aver_random_10L.append(np.mean(random_eps_i_10L))
    
  #%%%%%20L%%%%%%%%%  
  dqn_eps_i_20L = log_total_reward_DQL_20L[i:i+int(step)-1]
  aver_dqn_20L.append(np.mean(dqn_eps_i_20L))

  ddqn_eps_i_20L = log_total_reward_DDQN_20L[i:i+int(step)-1]
  aver_ddqn_20L.append(np.mean(ddqn_eps_i_20L))

  greedy_eps_i_20L = log_total_reward_greedy_20L[i:i+int(step)-1]
  aver_greedy_20L.append(np.mean(greedy_eps_i_20L))

  random_eps_i_20L = log_total_reward_ramdom_20L[i:i+int(step)-1]
  aver_random_20L.append(np.mean(random_eps_i_20L))
  i += 1

plt.grid()
plt.plot(aver_random_L, "-", label=' Random', linewidth=1.5)
plt.plot(aver_greedy_L, "-", label=' Greedy', linewidth=1.5)
plt.plot(aver_dqn_L, "-", label=' Proposed DQN', linewidth=1.5)
plt.plot(aver_ddqn_L, "-", label=' Proposed DDQN', linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel(" Total Reward")
plt.legend(loc = "best")
plt.savefig('Total_rw_L.pdf')

plt.figure()
plt.grid()
plt.plot(aver_random_10L, "-", label=' Random', linewidth=1.5)
plt.plot(aver_greedy_10L, "-", label=' Greedy', linewidth=1.5)
plt.plot(aver_dqn_10L, "-", label=' Proposed DQN', linewidth=1.5)
plt.plot(aver_ddqn_10L, "-", label=' Proposed DDQN', linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel(" Total Reward")
plt.legend(loc = "best")
plt.savefig('Total_rw_10L.pdf')

plt.figure()
plt.grid()
plt.plot(aver_random_20L, "-", label=' Random', linewidth=1.5)
plt.plot(aver_greedy_20L, "-", label=' Greedy', linewidth=1.5)
plt.plot(aver_dqn_20L, "-", label=' Proposed DQN', linewidth=1.5)
plt.plot(aver_ddqn_20L, "-", label=' Proposed DDQN', linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel(" Total Reward")
plt.legend(loc = "best")
plt.savefig('Total_rw_20L.pdf')

plt.show()

# %%
############### Plot 2##################################
aver_comp_dqn_L = []
aver_comp_ddqn_L = []
aver_comp_greedy_L = []
aver_comp_random_L = []
aver_comp_dqn_10L = []
aver_comp_ddqn_10L = []
aver_comp_greedy_10L = []
aver_comp_random_10L = []
aver_comp_dqn_20L = []
aver_comp_ddqn_20L = []
aver_comp_greedy_20L = []
aver_comp_random_20L = []
num_episodes = 100
step = (len(log_total_reward_DQL_L)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_L), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_L = Comp_reward_DQL_L[i:i+int(step)-1]
  aver_comp_dqn_L.append(np.mean(dqn_eps_i_L))

  ddqn_eps_i_L = Comp_reward_DDQN_L[i:i+int(step)-1]
  aver_comp_ddqn_L.append(np.mean(ddqn_eps_i_L))

  greedy_eps_i_L = Comp_greedy_L[i:i+int(step)-1]
  aver_comp_greedy_L.append(np.mean(greedy_eps_i_L))

  random_eps_i_L = Comp_reward_ramdom_L[i:i+int(step)-1]
  aver_comp_random_L.append(np.mean(random_eps_i_L))

  #%%%%%10L%%%%%%%%%  
  dqn_eps_i_10L = Comp_reward_DQL_10L[i:i+int(step)-1]
  aver_comp_dqn_10L.append(np.mean(dqn_eps_i_10L))

  ddqn_eps_i_10L = Comp_reward_DDQN_10L[i:i+int(step)-1]
  aver_comp_ddqn_10L.append(np.mean(ddqn_eps_i_10L))

  greedy_eps_i_10L = Comp_greedy_10L[i:i+int(step)-1]
  aver_comp_greedy_10L.append(np.mean(greedy_eps_i_10L))

  random_eps_i_10L = Comp_reward_ramdom_10L[i:i+int(step)-1]
  aver_comp_random_10L.append(np.mean(random_eps_i_10L))
  i += 1
    
  #%%%%%20L%%%%%%%%%  
  dqn_eps_i_20L = Comp_reward_DQL_20L[i:i+int(step)-1]
  aver_comp_dqn_20L.append(np.mean(dqn_eps_i_20L))

  ddqn_eps_i_20L = Comp_reward_DDQN_20L[i:i+int(step)-1]
  aver_comp_ddqn_20L.append(np.mean(ddqn_eps_i_20L))

  greedy_eps_i_20L = Comp_greedy_20L[i:i+int(step)-1]
  aver_comp_greedy_20L.append(np.mean(greedy_eps_i_20L))

  random_eps_i_20L = Comp_reward_ramdom_20L[i:i+int(step)-1]
  aver_comp_random_20L.append(np.mean(random_eps_i_20L))
  i += 1
# L
rw_comp_dqn_L = np.mean(aver_comp_dqn_L[:][50:-1])
rw_comp_ddqn_L = np.mean(aver_comp_ddqn_L[:][50:-1])
rw_comp_greedy_L = np.mean(aver_comp_greedy_L[:][50:-1])
rw_comp_random_L = np.mean(aver_comp_random_L[:][50:-1])
# 10L
rw_comp_dqn_10L = np.mean(aver_comp_dqn_10L[50:-1])
rw_comp_ddqn_10L = np.mean(aver_comp_ddqn_10L[50:-1])
rw_comp_greedy_10L = np.mean(aver_comp_greedy_10L[50:-1])
rw_comp_random_10L = np.mean(aver_comp_random_10L[50:-1])
# 20L
rw_comp_dqn_20L = np.mean(aver_comp_dqn_20L[:][50:-1])
rw_comp_ddqn_20L = np.mean(aver_comp_ddqn_20L[:][50:-1])
rw_comp_greedy_20L = np.mean(aver_comp_greedy_20L[:][50:-1])
rw_comp_random_20L = np.mean(aver_comp_random_20L[:][50:-1])
#
rw_comp_dqn = [rw_comp_dqn_L, rw_comp_dqn_10L, rw_comp_dqn_20L]
RWCOMP_DQN = [a/alpha1 for a in rw_comp_dqn]
rw_comp_ddqn = [rw_comp_ddqn_L, rw_comp_ddqn_10L, rw_comp_ddqn_20L]
RWCOMP_DDQN = [a/alpha1 for a in rw_comp_ddqn]
rw_comp_greedy = [rw_comp_greedy_L, rw_comp_greedy_10L, rw_comp_greedy_20L]
RWCOMP_greedy = [a/alpha1 for a in rw_comp_greedy]
rw_comp_random = [rw_comp_random_L, rw_comp_random_10L, rw_comp_random_20L]
RWCOMP_random = [a/alpha1 for a in rw_comp_random]
x_Label = ["L", "10L", "20L"]

    
plt.figure()
plt.grid()
plt.plot(x_Label, RWCOMP_random, "s-.", label=' Random', linewidth=1.5)
plt.plot(x_Label, RWCOMP_greedy, "v--", label=' Greedy', linewidth=1.5)
plt.plot(x_Label, RWCOMP_DQN, "o:", label=' Proposed DQN', linewidth=1.5)
plt.plot(x_Label, RWCOMP_DDQN, "D-", label=' Proposed DDQN', linewidth=1.5)

plt.xlabel("Task size(L)")
plt.ylabel(" Computation Reward")
plt.legend(loc = "best")
plt.savefig('Comp_rw_L.pdf')
plt.show()

# %%
############### Plot 2##################################
aver_cost_dqn_L = []
aver_cost_ddqn_L = []
aver_cost_greedy_L = []
aver_cost_random_L = []
aver_cost_dqn_10L = []
aver_cost_ddqn_10L = []
aver_cost_greedy_10L = []
aver_cost_random_10L = []
aver_cost_dqn_20L = []
aver_cost_ddqn_20L = []
aver_cost_greedy_20L = []
aver_cost_random_20L = []
num_episodes = 100
step = (len(log_total_reward_DQL_L)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_L), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_L = Cost_reward_DQL_L[i:i+int(step)-1]
  aver_cost_dqn_L.append(np.mean(dqn_eps_i_L))

  ddqn_eps_i_L = Cost_reward_DDQN_L[i:i+int(step)-1]
  aver_cost_ddqn_L.append(np.mean(ddqn_eps_i_L))

  greedy_eps_i_L = Cost_greedy_L[i:i+int(step)-1]
  aver_cost_greedy_L.append(np.mean(greedy_eps_i_L))

  random_eps_i_L = Cost_reward_ramdom_L[i:i+int(step)-1]
  aver_cost_random_L.append(np.mean(random_eps_i_L))

  #%%%%%%10L%%%%%%%%%
  dqn_eps_i_10L = Cost_reward_DQL_10L[i:i+int(step)-1]
  aver_cost_dqn_10L.append(np.mean(dqn_eps_i_10L))

  ddqn_eps_i_10L = Cost_reward_DDQN_10L[i:i+int(step)-1]
  aver_cost_ddqn_10L.append(np.mean(ddqn_eps_i_10L))

  greedy_eps_i_10L = Cost_greedy_10L[i:i+int(step)-1]
  aver_cost_greedy_10L.append(np.mean(greedy_eps_i_10L))

  random_eps_i_10L = Cost_reward_ramdom_10L[i:i+int(step)-1]
  aver_cost_random_10L.append(np.mean(random_eps_i_10L))

    
  #%%%%%20L%%%%%%%%%  
  dqn_eps_i_20L = Cost_reward_DQL_20L[i:i+int(step)-1]
  aver_cost_dqn_20L.append(np.mean(dqn_eps_i_20L))

  ddqn_eps_i_20L = Cost_reward_DDQN_20L[i:i+int(step)-1]
  aver_cost_ddqn_20L.append(np.mean(ddqn_eps_i_20L))

  greedy_eps_i_20L = Cost_greedy_20L[i:i+int(step)-1]
  aver_cost_greedy_20L.append(np.mean(greedy_eps_i_20L))

  random_eps_i_20L = Cost_reward_ramdom_20L[i:i+int(step)-1]
  aver_cost_random_20L.append(np.mean(random_eps_i_20L))
  i += 1
    
# L
rw_cost_dqn_L = np.mean(aver_cost_dqn_L[:][50:-1])
rw_cost_ddqn_L = np.mean(aver_cost_ddqn_L[:][50:-1])
rw_cost_greedy_L = np.mean(aver_cost_greedy_L[:][50:-1])
rw_cost_random_L = np.mean(aver_cost_random_L[:][50:-1])
# 10L
rw_cost_dqn_10L = np.mean(aver_cost_dqn_10L[50:-1])
rw_cost_ddqn_10L = np.mean(aver_cost_ddqn_10L[50:-1])
rw_cost_greedy_10L = np.mean(aver_cost_greedy_10L[50:-1])
rw_cost_random_10L = np.mean(aver_cost_random_10L[50:-1])
# 20L
rw_cost_dqn_20L = np.mean(aver_cost_dqn_20L[:][50:-1])
rw_cost_ddqn_20L = np.mean(aver_cost_ddqn_20L[:][50:-1])
rw_cost_greedy_20L = np.mean(aver_cost_greedy_20L[:][50:-1])
rw_cost_random_20L = np.mean(aver_cost_random_20L[:][50:-1])
#
rw_cost_dqn = [rw_cost_dqn_L, rw_cost_dqn_10L, rw_cost_dqn_20L]
RWCOST_DQN = [a/alpha2 for a in rw_cost_dqn]
rw_cost_ddqn = [rw_cost_ddqn_L, rw_cost_ddqn_10L, rw_cost_ddqn_20L]
RWCOST_DDQN = [a/alpha2 for a in rw_cost_ddqn]
rw_cost_greedy = [rw_cost_greedy_L, rw_cost_greedy_10L, rw_cost_greedy_20L]
RWCOST_greedy = [a/alpha2 for a in rw_cost_greedy]
rw_cost_random = [rw_cost_random_L, rw_cost_random_10L, rw_cost_random_20L]
RWCOST_random = [a/alpha2 for a in rw_cost_random]
x_Label = ["L", "10L", "20L"]
plt.figure()
plt.grid()
plt.plot(x_Label, RWCOST_random, "s-.", label=' Random', linewidth=1.5)
plt.plot(x_Label, RWCOST_greedy, "v--", label=' Greedy', linewidth=1.5)
plt.plot(x_Label, RWCOST_DQN, "o:", label=' Proposed DQN', linewidth=1.5)
plt.plot(x_Label, RWCOST_DDQN, "D-", label=' Proposed DDQN', linewidth=1.5)


plt.xlabel("Task size(L)")
plt.ylabel(" Cost Reward")
plt.legend(loc = "best")
plt.savefig('Cost_rw_L.pdf')
plt.show()

# %%
############### Plot 2##################################
aver_Res_dqn_L = []
aver_Res_ddqn_L = []
aver_Res_greedy_L = []
aver_Res_random_L = []
aver_Res_dqn_10L = []
aver_Res_ddqn_10L = []
aver_Res_greedy_10L = []
aver_Res_random_10L = []
aver_Res_dqn_20L = []
aver_Res_ddqn_20L = []
aver_Res_greedy_20L = []
aver_Res_random_20L = []
num_episodes = 100
step = (len(log_total_reward_DQL_L)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_L), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_L = Res_reward_DQL_L[i:i+int(step)-1]
  aver_Res_dqn_L.append(np.mean(dqn_eps_i_L))

  ddqn_eps_i_L = Res_reward_DDQN_L[i:i+int(step)-1]
  aver_Res_ddqn_L.append(np.mean(ddqn_eps_i_L))

  greedy_eps_i_L = Res_greedy_L[i:i+int(step)-1]
  aver_Res_greedy_L.append(np.mean(greedy_eps_i_L))

  random_eps_i_L = Res_reward_ramdom_L[i:i+int(step)-1]
  aver_Res_random_L.append(np.mean(random_eps_i_L))

  #%%%%%%10L%%%%%%%%%
  dqn_eps_i_10L = Res_reward_DQL_10L[i:i+int(step)-1]
  aver_Res_dqn_10L.append(np.mean(dqn_eps_i_10L))

  ddqn_eps_i_10L = Res_reward_DDQN_10L[i:i+int(step)-1]
  aver_Res_ddqn_10L.append(np.mean(ddqn_eps_i_10L))

  greedy_eps_i_10L = Res_greedy_10L[i:i+int(step)-1]
  aver_Res_greedy_10L.append(np.mean(greedy_eps_i_10L))

  random_eps_i_10L = Res_reward_ramdom_10L[i:i+int(step)-1]
  aver_Res_random_10L.append(np.mean(random_eps_i_10L))
    
  #%%%%%20L%%%%%%%%%  
  dqn_eps_i_20L = Res_reward_DQL_20L[i:i+int(step)-1]
  aver_Res_dqn_20L.append(np.mean(dqn_eps_i_20L))

  ddqn_eps_i_20L = Res_reward_DDQN_20L[i:i+int(step)-1]
  aver_Res_ddqn_20L.append(np.mean(ddqn_eps_i_20L))

  greedy_eps_i_20L = Res_greedy_20L[i:i+int(step)-1]
  aver_Res_greedy_20L.append(np.mean(greedy_eps_i_20L))

  random_eps_i_20L = Res_reward_ramdom_20L[i:i+int(step)-1]
  aver_Res_random_20L.append(np.mean(random_eps_i_20L))
  i += 1
    
# L
rw_Res_dqn_L = np.mean(aver_Res_dqn_L[:][70:-1])
rw_Res_ddqn_L = np.mean(aver_Res_ddqn_L[:][70:-1])
rw_Res_greedy_L = np.mean(aver_Res_greedy_L[:][70:-1])
rw_Res_random_L = np.mean(aver_Res_random_L[:][70:-1])
# 10L
rw_Res_dqn_10L = np.mean(aver_Res_dqn_10L[:][70:-1])
rw_Res_ddqn_10L = np.mean(aver_Res_ddqn_10L[:][70:-1])
rw_Res_greedy_10L = np.mean(aver_Res_greedy_10L[:][70:-1])
rw_Res_random_10L = np.mean(aver_Res_random_10L[:][70:-1])
# 20L
rw_Res_dqn_20L = np.mean(aver_Res_dqn_20L[:][70:-1])
rw_Res_ddqn_20L = np.mean(aver_Res_ddqn_20L[:][70:-1])
rw_Res_greedy_20L = np.mean(aver_Res_greedy_20L[:][70:-1])
rw_Res_random_20L = np.mean(aver_Res_random_20L[:][70:-1])
#
rw_Res_dqn = [rw_Res_dqn_L, rw_Res_dqn_10L, rw_Res_dqn_20L]
RWRES_DQN = [a/alpha3 for a in rw_Res_dqn]
rw_Res_ddqn = [rw_Res_ddqn_L, rw_Res_ddqn_10L, rw_Res_ddqn_20L]
RWRES_DDQN = [a/alpha3 for a in rw_Res_ddqn]
rw_Res_greedy = [rw_Res_greedy_L,  rw_Res_greedy_10L, rw_Res_greedy_20L]
RWRES_greedy = [a/alpha3 for a in rw_Res_greedy]
rw_Res_random = [rw_Res_random_L, rw_Res_random_10L, rw_Res_random_20L]
RWRES_random = [a/alpha3 for a in rw_Res_random]
x_Label = ["L", "10L", "20L"]
plt.figure()
plt.grid()
plt.plot(x_Label, RWRES_random, "s-.", label=' Random', linewidth=1.5)
plt.plot(x_Label, RWRES_greedy, "v--", label=' Greedy', linewidth=1.5)
plt.plot(x_Label, RWRES_DQN, "o:", label=' Proposed DQN', linewidth=1.5)
plt.plot(x_Label, RWRES_DDQN, "D-", label=' Proposed DDQN', linewidth=1.5)

plt.xlabel("Task size(L)")
plt.ylabel(" Res Reward")
plt.legend(loc = "best")
plt.savefig('Res_rw_L.pdf')
plt.show()

# %%
############### Plot 2##################################
aver_Connect_dqn_L = []
aver_Connect_ddqn_L = []
aver_Connect_greedy_L = []
aver_Connect_random_L = []
aver_Connect_dqn_10L = []
aver_Connect_ddqn_10L = []
aver_Connect_greedy_10L = []
aver_Connect_random_10L = []
aver_Connect_dqn_20L = []
aver_Connect_ddqn_20L = []
aver_Connect_greedy_20L = []
aver_Connect_random_20L = []
num_episodes = 100
step = (len(log_total_reward_DQL_L)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_L), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_L = Connect_reward_DQL_L[i:i+int(step)-1]
  aver_Connect_dqn_L.append(np.mean(dqn_eps_i_L))

  ddqn_eps_i_L = Connect_reward_DDQN_L[i:i+int(step)-1]
  aver_Connect_ddqn_L.append(np.mean(ddqn_eps_i_L))

  greedy_eps_i_L = Connect_greedy_L[i:i+int(step)-1]
  aver_Connect_greedy_L.append(np.mean(greedy_eps_i_L))

  random_eps_i_L = Connect_reward_ramdom_L[i:i+int(step)-1]
  aver_Connect_random_L.append(np.mean(random_eps_i_L))

  #%%%%%%10L%%%%%%%%%
  dqn_eps_i_10L = Connect_reward_DQL_10L[i:i+int(step)-1]
  aver_Connect_dqn_10L.append(np.mean(dqn_eps_i_10L))

  ddqn_eps_i_10L = Connect_reward_DDQN_10L[i:i+int(step)-1]
  aver_Connect_ddqn_10L.append(np.mean(ddqn_eps_i_10L))

  greedy_eps_i_10L = Connect_greedy_10L[i:i+int(step)-1]
  aver_Connect_greedy_10L.append(np.mean(greedy_eps_i_10L))

  random_eps_i_10L = Connect_reward_ramdom_10L[i:i+int(step)-1]
  aver_Connect_random_10L.append(np.mean(random_eps_i_10L))
    
  #%%%%%20L%%%%%%%%%  
  dqn_eps_i_20L = Connect_reward_DQL_20L[i:i+int(step)-1]
  aver_Connect_dqn_20L.append(np.mean(dqn_eps_i_20L))

  ddqn_eps_i_20L = Connect_reward_DDQN_20L[i:i+int(step)-1]
  aver_Connect_ddqn_20L.append(np.mean(ddqn_eps_i_20L))

  greedy_eps_i_20L = Connect_greedy_20L[i:i+int(step)-1]
  aver_Connect_greedy_20L.append(np.mean(greedy_eps_i_20L))

  random_eps_i_20L = Connect_reward_ramdom_20L[i:i+int(step)-1]
  aver_Connect_random_20L.append(np.mean(random_eps_i_20L))
  i += 1
    
# L
rw_Connect_dqn_L = np.mean(aver_Connect_dqn_L[:][50:-1])
rw_Connect_ddqn_L = np.mean(aver_Connect_ddqn_L[:][50:-1])
rw_Connect_greedy_L = np.mean(aver_Connect_greedy_L[:][50:-1])
rw_Connect_random_L = np.mean(aver_Connect_random_L[:][50:-1])
# 10L
rw_Connect_dqn_10L = np.mean(aver_Connect_dqn_10L[50:-1])
rw_Connect_ddqn_10L = np.mean(aver_Connect_ddqn_10L[50:-1])
rw_Connect_greedy_10L = np.mean(aver_Connect_greedy_10L[50:-1])
rw_Connect_random_10L = np.mean(aver_Connect_random_10L[50:-1])
# 20L
rw_Connect_dqn_20L = np.mean(aver_Connect_dqn_20L[:][50:-1])
rw_Connect_ddqn_20L = np.mean(aver_Connect_ddqn_20L[:][50:-1])
rw_Connect_greedy_20L = np.mean(aver_Connect_greedy_20L[:][50:-1])
rw_Connect_random_20L = np.mean(aver_Connect_random_20L[:][50:-1])
#
rw_Connect_dqn = [rw_Connect_dqn_L, rw_Connect_dqn_10L, rw_Connect_dqn_20L]
RWCONNECT_DQN = [a/alpha4 for a in rw_Connect_dqn]
rw_Connect_ddqn = [rw_Connect_ddqn_L, rw_Connect_ddqn_10L, rw_Connect_ddqn_20L]
RWCONNECT_DDQN = [a/alpha4 for a in rw_Connect_ddqn]
rw_Connect_greedy = [rw_Connect_greedy_L, rw_Connect_greedy_10L, rw_Connect_greedy_20L]
RWCONNECT_greedy  = [a/alpha4 for a in rw_Connect_greedy]
rw_Connect_random = [rw_Connect_random_L, rw_Connect_random_10L, rw_Connect_random_20L]
RWRES_random = [a/alpha4 for a in rw_Connect_random]
x_Label = ["L", "10L", "20L"]
plt.figure()
plt.grid()
plt.plot(x_Label, RWRES_random, "s-.", label=' Random', linewidth=1.5)
plt.plot(x_Label, RWCONNECT_greedy, "v--", label=' Greedy', linewidth=1.5)
plt.plot(x_Label, RWCONNECT_DQN, "o:", label=' Proposed DQN', linewidth=1.5)
plt.plot(x_Label, RWCONNECT_DDQN, "D-", label=' Proposed DDQN', linewidth=1.5)

plt.xlabel("Task size(L)")
plt.ylabel(" Connect Reward")
plt.legend(loc = "best")
plt.savefig('Connect_rw_L.pdf')
plt.show()
