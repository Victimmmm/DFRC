# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
alpha1 = 5
alpha2 = 1.0
alpha3 = 5
alpha4 = 5
#%%%%%%%%%%%%%%%%%%%%%%%%%% DQL%%%%%%%%%%%%%%%%%%%%%%
dql_Pmax = pd.read_csv ("07_09_2022_05_54_46_DQN_total_rw.csv", names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
dql_Pmax = np.array(dql_Pmax)
dql_Pmax  = np.transpose(dql_Pmax) 
log_total_reward_DQL_Pmax = dql_Pmax[0]
Comp_reward_DQL_Pmax = dql_Pmax[1]
Cost_reward_DQL_Pmax = dql_Pmax[2]
Res_reward_DQL_Pmax = dql_Pmax[3]
Connect_reward_DQL_Pmax = dql_Pmax[4]
#%
dql_250Pmax = pd.read_csv ("08_09_2022_00_48_58_DQN_total_rw_250Pmax.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
dql_250Pmax = np.array(dql_250Pmax)
dql_250Pmax  = np.transpose(dql_250Pmax)
log_total_reward_DQL_250Pmax = dql_250Pmax[0]
Comp_reward_DQL_250Pmax = dql_250Pmax[1]
Cost_reward_DQL_250Pmax = dql_250Pmax[2]
Res_reward_DQL_250Pmax = dql_250Pmax[3]
Connect_reward_DQL_250Pmax = dql_250Pmax[4]
#%
dql_300Pmax = pd.read_csv ("08_09_2022_10_39_50_DQN_total_rw_300Pmax.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
dql_300Pmax = np.array(dql_300Pmax)
dql_300Pmax  = np.transpose(dql_300Pmax)  
log_total_reward_DQL_300Pmax = dql_300Pmax[0]
Comp_reward_DQL_300Pmax = dql_300Pmax[1]
Cost_reward_DQL_300Pmax = dql_300Pmax[2]
Res_reward_DQL_300Pmax = dql_300Pmax[3]
Connect_reward_DQL_300Pmax = dql_300Pmax[4]

#%%%%%%%%%%%%%%%%%%%%%%%%%% DDQL%%%%%%%%%%%%%%%%%%%%%%
ddqn_Pmax = pd.read_csv ("04_09_2022_00_01_02_DDQN_run.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ddqn_Pmax = np.array(ddqn_Pmax)
ddqn_Pmax  = np.transpose(ddqn_Pmax)  
log_total_reward_DDQN_Pmax = ddqn_Pmax[0]
Comp_reward_DDQN_Pmax = ddqn_Pmax[1]
Cost_reward_DDQN_Pmax = ddqn_Pmax[2]
Res_reward_DDQN_Pmax = ddqn_Pmax[3]
Connect_reward_DDQN_Pmax = ddqn_Pmax[4]
#%
ddqn_250Pmax = pd.read_csv ("08_09_2022_09_07_48_DDQN_250Pmax.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ddqn_250Pmax = np.array(ddqn_250Pmax)
ddqn_250Pmax  = np.transpose(ddqn_250Pmax)  
log_total_reward_DDQN_250Pmax = ddqn_250Pmax[0]
Comp_reward_DDQN_250Pmax = ddqn_250Pmax[1]
Cost_reward_DDQN_250Pmax = ddqn_250Pmax[2]
Res_reward_DDQN_250Pmax = ddqn_250Pmax[3]
Connect_reward_DDQN_250Pmax = ddqn_250Pmax[4]
#%
ddqn_300Pmax = pd.read_csv ("09_09_2022_01_49_30_DDQN_300Pmax.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ddqn_300Pmax = np.array(ddqn_300Pmax)
ddqn_300Pmax  = np.transpose(ddqn_300Pmax)  
log_total_reward_DDQN_300Pmax = ddqn_300Pmax[0]
Comp_reward_DDQN_300Pmax = ddqn_300Pmax[1]
Cost_reward_DDQN_300Pmax = ddqn_300Pmax[2]
Res_reward_DDQN_300Pmax = ddqn_300Pmax[3]
Connect_reward_DDQN_300Pmax = ddqn_300Pmax[4]

#%%%%%%%%%%%%%%%%%%%%%%%%%% Random%%%%%%%%%%%%%%%%%%%%%%
ramdom_Pmax = pd.read_csv ("05_09_2022_01_48_32_Random_total_rw.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ramdom_Pmax = np.array(ramdom_Pmax)
ramdom_Pmax  = np.transpose(ramdom_Pmax)  
log_total_reward_ramdom_Pmax = ramdom_Pmax[0]
Comp_reward_ramdom_Pmax = ramdom_Pmax[1]
Cost_reward_ramdom_Pmax = ramdom_Pmax[2]
Res_reward_ramdom_Pmax = ramdom_Pmax[3]
Connect_reward_ramdom_Pmax = ramdom_Pmax[4]
#%
ramdom_250Pmax = pd.read_csv ("08_09_2022_15_59_49_Random_250Pmax.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ramdom_250Pmax = np.array(ramdom_250Pmax)
ramdom_250Pmax  = np.transpose(ramdom_250Pmax)  
log_total_reward_ramdom_250Pmax = ramdom_250Pmax[0]
Comp_reward_ramdom_250Pmax = ramdom_250Pmax[1]
Cost_reward_ramdom_250Pmax = ramdom_250Pmax[2]
Res_reward_ramdom_250Pmax = ramdom_250Pmax[3]
Connect_reward_ramdom_250Pmax = ramdom_250Pmax[4]
#%
ramdom_300Pmax = pd.read_csv ("09_09_2022_00_10_54_Random_300Pmax.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
ramdom_300Pmax = np.array(ramdom_300Pmax)
ramdom_300Pmax  = np.transpose(ramdom_300Pmax)  
log_total_reward_ramdom_300Pmax = ramdom_300Pmax[0]
Comp_reward_ramdom_300Pmax = ramdom_300Pmax[1]
Cost_reward_ramdom_300Pmax = ramdom_300Pmax[2]
Res_reward_ramdom_300Pmax = ramdom_300Pmax[3]
Connect_reward_ramdom_300Pmax = ramdom_300Pmax[4]

#%%%%%%%%%%%%%%%%%%%%%%%%%% Greedy%%%%%%%%%%%%%%%%%%%%%%
greedy_Pmax = pd.read_csv ("05_09_2022_01_57_06_Greedy_total_rw.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
greedy_Pmax = np.array(greedy_Pmax)
greedy_Pmax  = np.transpose(greedy_Pmax)  
log_total_reward_greedy_Pmax = greedy_Pmax[0]
Comp_greedy_Pmax = greedy_Pmax[1]
Cost_greedy_Pmax = greedy_Pmax[2]
Res_greedy_Pmax = greedy_Pmax[3]
Connect_greedy_Pmax = greedy_Pmax[4]
#%
greedy_250Pmax = pd.read_csv ("08_09_2022_13_08_28_Greedy_250Pmax.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
greedy_250Pmax = np.array(greedy_250Pmax)
greedy_250Pmax  = np.transpose(greedy_250Pmax) 
log_total_reward_greedy_250Pmax = greedy_250Pmax[0]
Comp_greedy_250Pmax = greedy_250Pmax[1]
Cost_greedy_250Pmax = greedy_250Pmax[2]
Res_greedy_250Pmax = greedy_250Pmax[3]
Connect_greedy_250Pmax = greedy_250Pmax[4]
#%
greedy_300Pmax = pd.read_csv ("08_09_2022_13_13_40_Greedy_300Pmax.csv",names = ['Total rw', 'Computation rw', 'Cost rw', 'Res rw', 'Connect rw'])   
greedy_300Pmax = np.array(greedy_300Pmax)
greedy_300Pmax  = np.transpose(greedy_300Pmax)  
log_total_reward_greedy_300Pmax = greedy_300Pmax[0]
Comp_greedy_300Pmax = greedy_300Pmax[1]
Cost_greedy_300Pmax = greedy_300Pmax[2]
Res_greedy_300Pmax = greedy_300Pmax[3]
Connect_greedy_300Pmax = greedy_300Pmax[4]

# %%
############### Plot 2##################################
aver_dqn_Pmax = []
aver_ddqn_Pmax = []
aver_greedy_Pmax = []
aver_random_Pmax = []
aver_dqn_250Pmax = []
aver_ddqn_250Pmax = []
aver_greedy_250Pmax = []
aver_random_250Pmax = []
aver_dqn_300Pmax = []
aver_ddqn_300Pmax = []
aver_greedy_300Pmax = []
aver_random_300Pmax = []
num_episodes = 100
step = (len(log_total_reward_DQL_Pmax)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_Pmax), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_Pmax = log_total_reward_DQL_Pmax[i:i+int(step)-1]
  aver_dqn_Pmax.append(np.mean(dqn_eps_i_Pmax))

  ddqn_eps_i_Pmax = log_total_reward_DDQN_Pmax[i:i+int(step)-1]
  aver_ddqn_Pmax.append(np.mean(ddqn_eps_i_Pmax))

  greedy_eps_i_Pmax = log_total_reward_greedy_Pmax[i:i+int(step)-1]
  aver_greedy_Pmax.append(np.mean(greedy_eps_i_Pmax))

  random_eps_i_Pmax = log_total_reward_ramdom_Pmax[i:i+int(step)-1]
  aver_random_Pmax.append(np.mean(random_eps_i_Pmax))

  # #%%%%%%250Pmax%%%%%%%%% 
  dqn_eps_i_250Pmax = log_total_reward_DQL_250Pmax[i:i+int(step)-1]
  aver_dqn_250Pmax.append(np.mean(dqn_eps_i_250Pmax))

  ddqn_eps_i_250Pmax = log_total_reward_DDQN_250Pmax[i:i+int(step)-1]
  aver_ddqn_250Pmax.append(np.mean(ddqn_eps_i_250Pmax))

  greedy_eps_i_250Pmax = log_total_reward_greedy_250Pmax[i:i+int(step)-1]
  aver_greedy_250Pmax.append(np.mean(greedy_eps_i_250Pmax))

  random_eps_i_250Pmax = log_total_reward_ramdom_250Pmax[i:i+int(step)-1]
  aver_random_250Pmax.append(np.mean(random_eps_i_250Pmax))
    
  #%%%%%300Pmax%%%%%%%%%  
  dqn_eps_i_300Pmax = log_total_reward_DQL_300Pmax[i:i+int(step)-1]
  aver_dqn_300Pmax.append(np.mean(dqn_eps_i_300Pmax))

  ddqn_eps_i_300Pmax = log_total_reward_DDQN_300Pmax[i:i+int(step)-1]
  aver_ddqn_300Pmax.append(np.mean(ddqn_eps_i_300Pmax))

  greedy_eps_i_300Pmax = log_total_reward_greedy_300Pmax[i:i+int(step)-1]
  aver_greedy_300Pmax.append(np.mean(greedy_eps_i_300Pmax))

  random_eps_i_300Pmax = log_total_reward_ramdom_300Pmax[i:i+int(step)-1]
  aver_random_300Pmax.append(np.mean(random_eps_i_300Pmax))
  i += 1


plt.figure()
plt.grid()
plt.plot(aver_random_250Pmax, "-", label=' Random', linewidth=1.5)
plt.plot(aver_greedy_250Pmax, "-", label=' Greedy', linewidth=1.5)
plt.plot(aver_dqn_250Pmax, "-", label=' Proposed DQN', linewidth=1.5)
plt.plot(aver_ddqn_250Pmax, "-", label=' Proposed DDQN', linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel(" Total Reward")
plt.legend(loc = "best")
plt.savefig('Total_rw_250Pmax.pdf')

plt.figure()
plt.grid()
plt.plot(aver_random_300Pmax, "-", label=' Random', linewidth=1.5)
plt.plot(aver_greedy_300Pmax, "-", label=' Greedy', linewidth=1.5)
plt.plot(aver_dqn_300Pmax, "-", label=' Proposed DQN', linewidth=1.5)
plt.plot(aver_ddqn_300Pmax, "-", label=' Proposed DDQN', linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel(" Total Reward")
plt.legend(loc = "best")
plt.savefig('Total_rw_300Pmax.pdf')

plt.show()

# %%
############### Plot 2##################################
aver_comp_dqn_Pmax = []
aver_comp_ddqn_Pmax = []
aver_comp_greedy_Pmax = []
aver_comp_random_Pmax = []
aver_comp_dqn_250Pmax = []
aver_comp_ddqn_250Pmax = []
aver_comp_greedy_250Pmax = []
aver_comp_random_250Pmax = []
aver_comp_dqn_300Pmax = []
aver_comp_ddqn_300Pmax = []
aver_comp_greedy_300Pmax = []
aver_comp_random_300Pmax = []
num_episodes = 100
step = (len(log_total_reward_DQL_Pmax)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_Pmax), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_Pmax = Comp_reward_DQL_Pmax[i:i+int(step)-1]
  aver_comp_dqn_Pmax.append(np.mean(dqn_eps_i_Pmax))

  ddqn_eps_i_Pmax = Comp_reward_DDQN_Pmax[i:i+int(step)-1]
  aver_comp_ddqn_Pmax.append(np.mean(ddqn_eps_i_Pmax))

  greedy_eps_i_Pmax = Comp_greedy_Pmax[i:i+int(step)-1]
  aver_comp_greedy_Pmax.append(np.mean(greedy_eps_i_Pmax))

  random_eps_i_Pmax = Comp_reward_ramdom_Pmax[i:i+int(step)-1]
  aver_comp_random_Pmax.append(np.mean(random_eps_i_Pmax))

  #%%%%%250Pmax%%%%%%%%%  
  dqn_eps_i_250Pmax = Comp_reward_DQL_250Pmax[i:i+int(step)-1]
  aver_comp_dqn_250Pmax.append(np.mean(dqn_eps_i_250Pmax))

  ddqn_eps_i_250Pmax = Comp_reward_DDQN_250Pmax[i:i+int(step)-1]
  aver_comp_ddqn_250Pmax.append(np.mean(ddqn_eps_i_250Pmax))

  greedy_eps_i_250Pmax = Comp_greedy_250Pmax[i:i+int(step)-1]
  aver_comp_greedy_250Pmax.append(np.mean(greedy_eps_i_250Pmax))

  random_eps_i_250Pmax = Comp_reward_ramdom_250Pmax[i:i+int(step)-1]
  aver_comp_random_250Pmax.append(np.mean(random_eps_i_250Pmax))
  i += 1
    
  #%%%%%300Pmax%%%%%%%%%  
  dqn_eps_i_300Pmax = Comp_reward_DQL_300Pmax[i:i+int(step)-1]
  aver_comp_dqn_300Pmax.append(np.mean(dqn_eps_i_300Pmax))

  ddqn_eps_i_300Pmax = Comp_reward_DDQN_300Pmax[i:i+int(step)-1]
  aver_comp_ddqn_300Pmax.append(np.mean(ddqn_eps_i_300Pmax))

  greedy_eps_i_300Pmax = Comp_greedy_300Pmax[i:i+int(step)-1]
  aver_comp_greedy_300Pmax.append(np.mean(greedy_eps_i_300Pmax))

  random_eps_i_300Pmax = Comp_reward_ramdom_300Pmax[i:i+int(step)-1]
  aver_comp_random_300Pmax.append(np.mean(random_eps_i_300Pmax))
  i += 1

# %%
# L
rw_comp_dqn_Pmax = np.mean(aver_comp_dqn_Pmax[:][50:-1])
rw_comp_ddqn_Pmax = np.mean(aver_comp_ddqn_Pmax[:][50:-1])
rw_comp_greedy_Pmax = np.mean(aver_comp_greedy_Pmax[:][50:-1])
rw_comp_random_Pmax = np.mean(aver_comp_random_Pmax[:][50:-1])
# 250Pmax
rw_comp_dqn_250Pmax = np.mean(aver_comp_dqn_250Pmax[50:-1])
rw_comp_ddqn_250Pmax = np.mean(aver_comp_ddqn_250Pmax[50:-1])
rw_comp_greedy_250Pmax = np.mean(aver_comp_greedy_250Pmax[50:-1])
rw_comp_random_250Pmax = np.mean(aver_comp_random_250Pmax[50:-1])
# 300Pmax
rw_comp_dqn_300Pmax = np.mean(aver_comp_dqn_300Pmax[:][50:-1])
rw_comp_ddqn_300Pmax = np.mean(aver_comp_ddqn_300Pmax[:][50:-1])
rw_comp_greedy_300Pmax = np.mean(aver_comp_greedy_300Pmax[:][50:-1])
rw_comp_random_300Pmax = np.mean(aver_comp_random_300Pmax[:][50:-1])
#
rw_comp_dqn = [rw_comp_dqn_Pmax, rw_comp_dqn_250Pmax, rw_comp_dqn_300Pmax]
RWCOMP_DQN = [a/alpha1 for a in rw_comp_dqn]
rw_comp_ddqn = [rw_comp_ddqn_Pmax, rw_comp_ddqn_250Pmax, rw_comp_ddqn_300Pmax]
RWCOMP_DDQN = [a/alpha1 for a in rw_comp_ddqn]
rw_comp_greedy = [rw_comp_greedy_Pmax, rw_comp_greedy_250Pmax, rw_comp_greedy_300Pmax]
RWCOMP_greedy = [a/alpha1 for a in rw_comp_greedy]
rw_comp_random = [rw_comp_random_Pmax, rw_comp_random_250Pmax, rw_comp_random_300Pmax]
RWCOMP_random = [a/alpha1 for a in rw_comp_random]
x_Pmaxabel = ["$P^{\max} = 200$", "$P^{\max} = 250$", "$P^{\max} = 300$"]
   
plt.figure()
plt.grid()
plt.plot(x_Pmaxabel, RWCOMP_random, "s-.", label=' Random', linewidth=1.5)
plt.plot(x_Pmaxabel, RWCOMP_greedy, "v--", label=' Greedy', linewidth=1.5)
plt.plot(x_Pmaxabel, RWCOMP_DQN, "o:", label=' Proposed DQN', linewidth=1.5)
plt.plot(x_Pmaxabel, RWCOMP_DDQN, "D-", label=' Proposed DDQN', linewidth=1.5)

plt.xlabel("mW")
plt.ylabel(" Computation Reward")
plt.legend(loc = "best")
plt.savefig('Comp_rw_Pmax.pdf')
plt.show()

# %%
############### Plot 2##################################
aver_cost_dqn_Pmax = []
aver_cost_ddqn_Pmax = []
aver_cost_greedy_Pmax = []
aver_cost_random_Pmax = []
aver_cost_dqn_250Pmax = []
aver_cost_ddqn_250Pmax = []
aver_cost_greedy_250Pmax = []
aver_cost_random_250Pmax = []
aver_cost_dqn_300Pmax = []
aver_cost_ddqn_300Pmax = []
aver_cost_greedy_300Pmax = []
aver_cost_random_300Pmax = []
num_episodes = 100
step = (len(log_total_reward_DQL_Pmax)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_Pmax), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_Pmax = Cost_reward_DQL_Pmax[i:i+int(step)-1]
  aver_cost_dqn_Pmax.append(np.mean(dqn_eps_i_Pmax))

  ddqn_eps_i_Pmax = Cost_reward_DDQN_Pmax[i:i+int(step)-1]
  aver_cost_ddqn_Pmax.append(np.mean(ddqn_eps_i_Pmax))

  greedy_eps_i_Pmax = Cost_greedy_Pmax[i:i+int(step)-1]
  aver_cost_greedy_Pmax.append(np.mean(greedy_eps_i_Pmax))

  random_eps_i_Pmax = Cost_reward_ramdom_Pmax[i:i+int(step)-1]
  aver_cost_random_Pmax.append(np.mean(random_eps_i_Pmax))

  #%%%%%%250Pmax%%%%%%%%%
  dqn_eps_i_250Pmax = Cost_reward_DQL_250Pmax[i:i+int(step)-1]
  aver_cost_dqn_250Pmax.append(np.mean(dqn_eps_i_250Pmax))

  ddqn_eps_i_250Pmax = Cost_reward_DDQN_250Pmax[i:i+int(step)-1]
  aver_cost_ddqn_250Pmax.append(np.mean(ddqn_eps_i_250Pmax))

  greedy_eps_i_250Pmax = Cost_greedy_250Pmax[i:i+int(step)-1]
  aver_cost_greedy_250Pmax.append(np.mean(greedy_eps_i_250Pmax))

  random_eps_i_250Pmax = Cost_reward_ramdom_250Pmax[i:i+int(step)-1]
  aver_cost_random_250Pmax.append(np.mean(random_eps_i_250Pmax))

    
  #%%%%%300Pmax%%%%%%%%%  
  dqn_eps_i_300Pmax = Cost_reward_DQL_300Pmax[i:i+int(step)-1]
  aver_cost_dqn_300Pmax.append(np.mean(dqn_eps_i_300Pmax))

  ddqn_eps_i_300Pmax = Cost_reward_DDQN_300Pmax[i:i+int(step)-1]
  aver_cost_ddqn_300Pmax.append(np.mean(ddqn_eps_i_300Pmax))

  greedy_eps_i_300Pmax = Cost_greedy_300Pmax[i:i+int(step)-1]
  aver_cost_greedy_300Pmax.append(np.mean(greedy_eps_i_300Pmax))

  random_eps_i_300Pmax = Cost_reward_ramdom_300Pmax[i:i+int(step)-1]
  aver_cost_random_300Pmax.append(np.mean(random_eps_i_300Pmax))
  i += 1
    
# L
rw_cost_dqn_Pmax = np.mean(aver_cost_dqn_Pmax[:][50:-1])
rw_cost_ddqn_Pmax = np.mean(aver_cost_ddqn_Pmax[:][50:-1])
rw_cost_greedy_Pmax = np.mean(aver_cost_greedy_Pmax[:][50:-1])
rw_cost_random_Pmax = np.mean(aver_cost_random_Pmax[:][50:-1])
# 250Pmax
rw_cost_dqn_250Pmax = np.mean(aver_cost_dqn_250Pmax[50:-1])
rw_cost_ddqn_250Pmax = np.mean(aver_cost_ddqn_250Pmax[50:-1])
rw_cost_greedy_250Pmax = np.mean(aver_cost_greedy_250Pmax[50:-1])
rw_cost_random_250Pmax = np.mean(aver_cost_random_250Pmax[50:-1])
# 300Pmax
rw_cost_dqn_300Pmax = np.mean(aver_cost_dqn_300Pmax[:][50:-1])
rw_cost_ddqn_300Pmax = np.mean(aver_cost_ddqn_300Pmax[:][50:-1])
rw_cost_greedy_300Pmax = np.mean(aver_cost_greedy_300Pmax[:][50:-1])
rw_cost_random_300Pmax = np.mean(aver_cost_random_300Pmax[:][50:-1])
#
rw_cost_dqn = [rw_cost_dqn_Pmax, rw_cost_dqn_250Pmax, rw_cost_dqn_300Pmax]
RWCOST_DQN = [a/alpha2 for a in rw_cost_dqn]
rw_cost_ddqn = [rw_cost_ddqn_Pmax, rw_cost_ddqn_250Pmax, rw_cost_ddqn_300Pmax]
RWCOST_DDQN = [a/alpha2 for a in rw_cost_ddqn]
rw_cost_greedy = [rw_cost_greedy_Pmax, rw_cost_greedy_250Pmax, rw_cost_greedy_300Pmax]
RWCOST_greedy = [a/alpha2 for a in rw_cost_greedy]
rw_cost_random = [rw_cost_random_Pmax, rw_cost_random_250Pmax, rw_cost_random_300Pmax]
RWCOST_random = [a/alpha2 for a in rw_cost_random]
x_Pmaxabel = ["$P^{\max} = 200$", "$P^{\max} = 250$", "$P^{\max} = 300$"]
plt.figure()
plt.grid()
plt.plot(x_Pmaxabel, RWCOST_random, "s-.", label=' Random', linewidth=1.5)
plt.plot(x_Pmaxabel, RWCOST_greedy, "v--", label=' Greedy', linewidth=1.5)
plt.plot(x_Pmaxabel, RWCOST_DQN, "o:", label=' Proposed DQN', linewidth=1.5)
plt.plot(x_Pmaxabel, RWCOST_DDQN, "D-", label=' Proposed DDQN', linewidth=1.5)
plt.xlabel("mW")
plt.ylabel("Cost Reward")
plt.legend(loc = "best")
plt.savefig('Cost_rw_Pmax.pdf')
plt.show()

# %%
############### Plot 2##################################
aver_Res_dqn_Pmax = []
aver_Res_ddqn_Pmax = []
aver_Res_greedy_Pmax = []
aver_Res_random_Pmax = []
aver_Res_dqn_250Pmax = []
aver_Res_ddqn_250Pmax = []
aver_Res_greedy_250Pmax = []
aver_Res_random_250Pmax = []
aver_Res_dqn_300Pmax = []
aver_Res_ddqn_300Pmax = []
aver_Res_greedy_300Pmax = []
aver_Res_random_300Pmax = []
num_episodes = 100
step = (len(log_total_reward_DQL_Pmax)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_Pmax), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_Pmax = Res_reward_DQL_Pmax[i:i+int(step)-1]
  aver_Res_dqn_Pmax.append(np.mean(dqn_eps_i_Pmax))

  ddqn_eps_i_Pmax = Res_reward_DDQN_Pmax[i:i+int(step)-1]
  aver_Res_ddqn_Pmax.append(np.mean(ddqn_eps_i_Pmax))

  greedy_eps_i_Pmax = Res_greedy_Pmax[i:i+int(step)-1]
  aver_Res_greedy_Pmax.append(np.mean(greedy_eps_i_Pmax))

  random_eps_i_Pmax = Res_reward_ramdom_Pmax[i:i+int(step)-1]
  aver_Res_random_Pmax.append(np.mean(random_eps_i_Pmax))

  #%%%%%%250Pmax%%%%%%%%%
  dqn_eps_i_250Pmax = Res_reward_DQL_250Pmax[i:i+int(step)-1]
  aver_Res_dqn_250Pmax.append(np.mean(dqn_eps_i_250Pmax))

  ddqn_eps_i_250Pmax = Res_reward_DDQN_250Pmax[i:i+int(step)-1]
  aver_Res_ddqn_250Pmax.append(np.mean(ddqn_eps_i_250Pmax))

  greedy_eps_i_250Pmax = Res_greedy_250Pmax[i:i+int(step)-1]
  aver_Res_greedy_250Pmax.append(np.mean(greedy_eps_i_250Pmax))

  random_eps_i_250Pmax = Res_reward_ramdom_250Pmax[i:i+int(step)-1]
  aver_Res_random_250Pmax.append(np.mean(random_eps_i_250Pmax))
    
  #%%%%%300Pmax%%%%%%%%%  
  dqn_eps_i_300Pmax = Res_reward_DQL_300Pmax[i:i+int(step)-1]
  aver_Res_dqn_300Pmax.append(np.mean(dqn_eps_i_300Pmax))

  ddqn_eps_i_300Pmax = Res_reward_DDQN_300Pmax[i:i+int(step)-1]
  aver_Res_ddqn_300Pmax.append(np.mean(ddqn_eps_i_300Pmax))

  greedy_eps_i_300Pmax = Res_greedy_300Pmax[i:i+int(step)-1]
  aver_Res_greedy_300Pmax.append(np.mean(greedy_eps_i_300Pmax))

  random_eps_i_300Pmax = Res_reward_ramdom_300Pmax[i:i+int(step)-1]
  aver_Res_random_300Pmax.append(np.mean(random_eps_i_300Pmax))
  i += 1
    
# L
rw_Res_dqn_Pmax = np.max(aver_Res_dqn_Pmax[:][50:-1])
rw_Res_ddqn_Pmax = np.max(aver_Res_ddqn_Pmax[:][50:-1])
rw_Res_greedy_Pmax = np.max(aver_Res_greedy_Pmax[:][50:-1])
rw_Res_random_Pmax = np.max(aver_Res_random_Pmax[:][50:-1])
# 250Pmax
rw_Res_dqn_250Pmax = np.max(aver_Res_dqn_250Pmax[:][50:-1])
rw_Res_ddqn_250Pmax = np.max(aver_Res_ddqn_250Pmax[:][50:-1])
rw_Res_greedy_250Pmax = np.max(aver_Res_greedy_250Pmax[:][50:-1])
rw_Res_random_250Pmax = np.max(aver_Res_random_250Pmax[:][50:-1])
# 300Pmax
rw_Res_dqn_300Pmax = np.max(aver_Res_dqn_300Pmax[:][50:-1])
rw_Res_ddqn_300Pmax = np.max(aver_Res_ddqn_300Pmax[:][50:-1])
rw_Res_greedy_300Pmax = np.max(aver_Res_greedy_300Pmax[:][50:-1])
rw_Res_random_300Pmax = np.max(aver_Res_random_300Pmax[:][50:-1])
#
x_Pmaxabel = ["$P^{\max} = 200$", "$P^{\max} = 250$", "$P^{\max} = 300$"]
rw_Res_dqn = [rw_Res_dqn_Pmax, rw_Res_dqn_250Pmax, rw_Res_dqn_300Pmax]
RWRES_DQN = [a/alpha3 for a in rw_Res_dqn]
rw_Res_ddqn = [rw_Res_ddqn_Pmax, rw_Res_ddqn_250Pmax, rw_Res_ddqn_300Pmax]
RWRES_DDQN = [a/alpha3 for a in rw_Res_ddqn]
rw_Res_greedy = [rw_Res_greedy_Pmax,  rw_Res_greedy_250Pmax, rw_Res_greedy_300Pmax]
RWRES_greedy = [a/alpha3 for a in rw_Res_greedy]
rw_Res_random = [rw_Res_random_Pmax, rw_Res_random_250Pmax, rw_Res_random_300Pmax]
RWRES_random = [a/alpha3 for a in rw_Res_random]
plt.figure()
plt.grid()
plt.plot(x_Pmaxabel, RWRES_random, "s-.", label=' Random', linewidth=1.5)
plt.plot(x_Pmaxabel, RWRES_greedy, "v--", label=' Greedy', linewidth=1.5)
plt.plot(x_Pmaxabel, RWRES_DQN, "o:", label=' Proposed DQN', linewidth=1.5)
plt.plot(x_Pmaxabel, RWRES_DDQN, "D-", label=' Proposed DDQN', linewidth=1.5)

plt.xlabel("mW")
plt.ylabel(" Res Reward")
plt.legend(loc = "best")
plt.savefig('Res_rw_Pmax.pdf')
plt.show()

# %%
############### Plot 2##################################
aver_Connect_dqn_Pmax = []
aver_Connect_ddqn_Pmax = []
aver_Connect_greedy_Pmax = []
aver_Connect_random_Pmax = []
aver_Connect_dqn_250Pmax = []
aver_Connect_ddqn_250Pmax = []
aver_Connect_greedy_250Pmax = []
aver_Connect_random_250Pmax = []
aver_Connect_dqn_300Pmax = []
aver_Connect_ddqn_300Pmax = []
aver_Connect_greedy_300Pmax = []
aver_Connect_random_300Pmax = []
num_episodes = 100
step = (len(log_total_reward_DQL_Pmax)+1)/num_episodes
for i in range(0, len(log_total_reward_DQL_Pmax), int(step)):
    
  #%%%%%%L%%%%%%%%%
  dqn_eps_i_Pmax = Connect_reward_DQL_Pmax[i:i+int(step)-1]
  aver_Connect_dqn_Pmax.append(np.mean(dqn_eps_i_Pmax))

  ddqn_eps_i_Pmax = Connect_reward_DDQN_Pmax[i:i+int(step)-1]
  aver_Connect_ddqn_Pmax.append(np.mean(ddqn_eps_i_Pmax))

  greedy_eps_i_Pmax = Connect_greedy_Pmax[i:i+int(step)-1]
  aver_Connect_greedy_Pmax.append(np.mean(greedy_eps_i_Pmax))

  random_eps_i_Pmax = Connect_reward_ramdom_Pmax[i:i+int(step)-1]
  aver_Connect_random_Pmax.append(np.mean(random_eps_i_Pmax))

  #%%%%%%250Pmax%%%%%%%%%
  dqn_eps_i_250Pmax = Connect_reward_DQL_250Pmax[i:i+int(step)-1]
  aver_Connect_dqn_250Pmax.append(np.mean(dqn_eps_i_250Pmax))

  ddqn_eps_i_250Pmax = Connect_reward_DDQN_250Pmax[i:i+int(step)-1]
  aver_Connect_ddqn_250Pmax.append(np.mean(ddqn_eps_i_250Pmax))

  greedy_eps_i_250Pmax = Connect_greedy_250Pmax[i:i+int(step)-1]
  aver_Connect_greedy_250Pmax.append(np.mean(greedy_eps_i_250Pmax))

  random_eps_i_250Pmax = Connect_reward_ramdom_250Pmax[i:i+int(step)-1]
  aver_Connect_random_250Pmax.append(np.mean(random_eps_i_250Pmax))
    
  #%%%%%300Pmax%%%%%%%%%  
  dqn_eps_i_300Pmax = Connect_reward_DQL_300Pmax[i:i+int(step)-1]
  aver_Connect_dqn_300Pmax.append(np.mean(dqn_eps_i_300Pmax))

  ddqn_eps_i_300Pmax = Connect_reward_DDQN_300Pmax[i:i+int(step)-1]
  aver_Connect_ddqn_300Pmax.append(np.mean(ddqn_eps_i_300Pmax))

  greedy_eps_i_300Pmax = Connect_greedy_300Pmax[i:i+int(step)-1]
  aver_Connect_greedy_300Pmax.append(np.mean(greedy_eps_i_300Pmax))

  random_eps_i_300Pmax = Connect_reward_ramdom_300Pmax[i:i+int(step)-1]
  aver_Connect_random_300Pmax.append(np.mean(random_eps_i_300Pmax))
  i += 1
    
# L
rw_Connect_dqn_Pmax = np.mean(aver_Connect_dqn_Pmax[:][50:-1])
rw_Connect_ddqn_Pmax = np.mean(aver_Connect_ddqn_Pmax[:][50:-1])
rw_Connect_greedy_Pmax = np.mean(aver_Connect_greedy_Pmax[:][50:-1])
rw_Connect_random_Pmax = np.mean(aver_Connect_random_Pmax[:][50:-1])
# 250Pmax
rw_Connect_dqn_250Pmax = np.mean(aver_Connect_dqn_250Pmax[50:-1])
rw_Connect_ddqn_250Pmax = np.mean(aver_Connect_ddqn_250Pmax[50:-1])
rw_Connect_greedy_250Pmax = np.mean(aver_Connect_greedy_250Pmax[50:-1])
rw_Connect_random_250Pmax = np.mean(aver_Connect_random_250Pmax[50:-1])
# 300Pmax
rw_Connect_dqn_300Pmax = np.mean(aver_Connect_dqn_300Pmax[:][50:-1])
rw_Connect_ddqn_300Pmax = np.mean(aver_Connect_ddqn_300Pmax[:][50:-1])
rw_Connect_greedy_300Pmax = np.mean(aver_Connect_greedy_300Pmax[:][50:-1])
rw_Connect_random_300Pmax = np.mean(aver_Connect_random_300Pmax[:][50:-1])
#
x_Pmaxabel = ["$P^{\max} = 200$", "$P^{\max} = 250$", "$P^{\max} = 300$"]
rw_Connect_dqn = [rw_Connect_dqn_Pmax, rw_Connect_dqn_250Pmax, rw_Connect_dqn_300Pmax]
RWCONNECT_DQN = [a/alpha4 for a in rw_Connect_dqn]
rw_Connect_ddqn = [rw_Connect_ddqn_Pmax, rw_Connect_ddqn_250Pmax, rw_Connect_ddqn_300Pmax]
RWCONNECT_DDQN = [a/alpha4 for a in rw_Connect_ddqn]
rw_Connect_greedy = [rw_Connect_greedy_Pmax, rw_Connect_greedy_250Pmax, rw_Connect_greedy_300Pmax]
RWCONNECT_greedy  = [a/alpha4 for a in rw_Connect_greedy]
rw_Connect_random = [rw_Connect_random_Pmax, rw_Connect_random_250Pmax, rw_Connect_random_300Pmax]
RWRES_random = [a/alpha4 for a in rw_Connect_random]

plt.figure()
plt.grid()
plt.plot(x_Pmaxabel, RWRES_random, "s-.", label=' Random', linewidth=1.5)
plt.plot(x_Pmaxabel, RWCONNECT_greedy, "v--", label=' Greedy', linewidth=1.5)
plt.plot(x_Pmaxabel, RWCONNECT_DQN, "o:", label=' Proposed DQN', linewidth=1.5)
plt.plot(x_Pmaxabel, RWCONNECT_DDQN, "D-", label=' Proposed DDQN', linewidth=1.5)
plt.xlabel("mW")
plt.ylabel(" Connect Reward")
plt.legend(loc = "best")
plt.savefig('Connect_rw_Pmax.pdf')
plt.show()
print(rw_Connect_greedy_300Pmax)
# Out:
# 0.3066113945578231
